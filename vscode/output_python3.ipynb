# %%
# %matplotlib inline

# %%
# simple test
import pandas as pd
abs_path = 'c:\\repositories\\data-analysis-notebooks\\anomaly-detection\\'
data_path = os.path.join(abs_path, 'data', 'sunspots.txt')
df = pd.read_csv(data_path, sep='\t')
df.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2ee631ec8c9f> in <module>()
#       2 import pandas as pd
#       3 abs_path = 'c:\\repositories\\data-analysis-notebooks\\anomaly-detection\\'
# ----> 4 data_path = os.path.join(abs_path, 'data', 'sunspots.txt')
#       5 df = pd.read_csv(data_path, sep='\t')
#       6 df.plot()
#
# NameError: name 'os' is not defined

# %%
import os 
cwd = os.getcwd()
print (' Current path: {0}'.format(cwd))
# Out:
#  Current path: C:\Program Files\Microsoft VS Code

# %%
# simple test
import pandas as pd
abs_path = 'c:\\repositories\\data-analysis-notebooks\\anomaly-detection\\'
data_path = os.path.join(abs_path, 'data', 'sunspots.txt')
df = pd.read_csv(data_path, sep='\t')
df.plot()
